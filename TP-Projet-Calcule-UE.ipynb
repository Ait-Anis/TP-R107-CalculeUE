# %% [markdown]
# # Calcule des moyennes des UE

# %%
R101=input("Quelle est votre moyenne dans le module R101 et son coeff dans l'UE 1 sous forme de tuple").split()
print (R101)
# Out:
# Quelle est votre moyenne dans le module R101 et son coeff dans l'UE 1 sous forme de tuple 10 5
# ['10', '5']

# %%
#Version 1

def calcule_moy():
    d=0
    somme=0
    for i in range(21):
        i=input("Quelle est votre moyenne dans le module et son coeff dans l'UE (la note en premier et le coeff apres séparé avec un espace.").split()
        somme+=int(i[0])*int(i[1])
        d+=int(i[1])
    moyenne=somme/d
    if moyenne<10:
        print("L'UE n'est pas validé.")
    else:
        print("L'UE est validé")
    return str(moyenne)[:6]
calcule_moy()
# Out:
# Quelle est votre moyenne dans le module et son coeff dans l'UE 1 (la note en premier et le coeff apres séparé avec un espace. 11 10
# Quelle est votre moyenne dans le module et son coeff dans l'UE 1 (la note en premier et le coeff apres séparé avec un espace. 8 10
# Quelle est votre moyenne dans le module et son coeff dans l'UE 1 (la note en premier et le coeff apres séparé avec un espace. 7 7
# Quelle est votre moyenne dans le module et son coeff dans l'UE 1 (la note en premier et le coeff apres séparé avec un espace. 16 7
# Quelle est votre moyenne dans le module et son coeff dans l'UE 1 (la note en premier et le coeff apres séparé avec un espace. 7 0
# Quelle est votre moyenne dans le module et son coeff dans l'UE 1 (la note en premier et le coeff apres séparé avec un espace. 11 5
# Quelle est votre moyenne dans le module et son coeff dans l'UE 1 (la note en premier et le coeff apres séparé avec un espace. 9 0
# ...

# %%
import random 
note=[random.randint(5,17) for n in range(21)]
coeff=[10,10,7,7,0,5,0,6,0,5,4,2,5,5,0,20,20,0,0,0,7]
print(note)
print(coeff)
# Out:
# [11, 8, 7, 16, 7, 11, 9, 10, 16, 8, 6, 13, 12, 17, 14, 12, 8, 14, 13, 12, 17]
# [10, 10, 7, 7, 0, 5, 0, 6, 0, 5, 4, 2, 5, 5, 0, 20, 20, 0, 0, 0, 7]

# %%
#Version 2

def calcul_moy():
    liste_note=[]
    liste_coeff=[]
    somme=0
    moyenne=0
    for i in range(21):
        R10=input("Quelle est votre moyenne dans vos modules et leur coeff Dans L'UE1 (mettez une note avec son coeff avec la note en premiere et le coeff ensuite et un espace entre eux").split()
        liste_note.append(int(R10[0]))
        liste_coeff.append(int(R10[1]))
    for i in range(len(liste_note)):
        somme+=liste_note[i]*liste_coeff[i]
    moyenne=somme/sum(liste_coeff)
    return moyenne




def UE():
    liste_UE=[]
    boole=True
    defaillant=[]
    for i in range(3):
        print("Vous allez d'abord entrer vos notes et coeff pour L'UE {}").format(i)
        liste_UE.append(float(calcul_moy()))
    for i in range(liste_UE):
        if liste_UE[i]<10:
            boole=False
            defaillant.append(i)
    if len(defaillant)==1:
        print("L'année n'est pas validé a cause de l'UE {0} et sa moyenne est de {1}.").format(defaillant[0],liste_UE[defaillant[0]-1])
    if len(defaillant)==2:
        print("L'année n'est pas validé a cause de l'UE {0} et sa moyenne est de {1}.").format(defaillant[0],liste_UE[defaillant[0]-1])
        print("L'année n'est pas validé a cause de l'UE {0} et sa moyenne est de {1}.").format(defaillant[1],liste_UE[defaillant[1]-1])
    if len(defaillant)>=2:
        print("L'année n'est pas validé et vous ne pouvez pas passer a l'année prochain.")
